# %% [markdown]
# ## 1. Datos Maestros de Productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
productos = pd.read_csv("productos.csv")

# %%
productos.sample(5)
# Out:
#          sku   categoria subcategoria talla   color  costo_unitario  \
# 71  HM000072  Pantalones    Temporada     L    Azul           26.81
# 78  HM000079     Abrigos    Temporada     S    Azul           37.58
# 89  HM000090    Vestidos    Temporada    XL    Rojo           36.08
# 36  HM000037   Camisetas      Premium    XS  Blanco            5.38
# 48  HM000049    Vestidos    Temporada    XS   Negro           31.69
#
#     precio_venta proveedor_id  lead_time_dias  cantidad_minima_pedido  \
# 71         65.24      PROV072               8                      50
# 78         62.52      PROV079              16                     200
# 89         77.71      PROV090              14                     500
# 36         58.90      PROV037              20                     200
# 48         72.45      PROV049              17                     500
#
#     multiplico_pedido    temporada  margen
# 71                 50    Primavera   38.43
# 78                 10     Invierno   24.94
# ...

# %% [markdown]
# ## 2. Datos Históricos de Ventas (365 días)

# %%
ventas = pd.read_csv('ventas.csv')

# %%
ventas.sample(5)
# Out:
#              fecha     tienda       sku  cantidad_vendida  \
# 442947  2023-06-22  TIENDA007  HM000069                 1
# 503084  2023-07-15  TIENDA008  HM000045                 1
# 917620  2023-12-23  TIENDA008  HM000040                 1
# 45992   2023-01-18  TIENDA009  HM000064                 2
# 924888  2023-12-26  TIENDA003  HM000024                 3
#
#         precio_venta_unitario  descuento_aplicado  venta_neta
# 442947                  30.26                 0.0      30.260
# 503084                  90.97                 0.0      90.970
# 917620                  59.59                 0.0      59.590
# 45992                   91.93                 0.1     165.474
# 924888                  98.10                 0.2     235.440

# %% [markdown]
# ## 3. Datos de Inventario Actual

# %%
inventario = pd.read_csv('inventario.csv')

# %%
inventario.sample(5)
# Out:
#         tienda       sku  stock_actual  stock_seguridad_actual  \
# 519  TIENDA006  HM000032            19                      16
# 295  TIENDA003  HM000061            24                      24
# 592  TIENDA006  HM000087             3                      27
# 10   TIENDA001  HM000019            81                      18
# 418  TIENDA005  HM000013             5                      24
#
#      stock_en_transito fecha_ultima_reposicion
# 519                  8              2023-12-28
# 295                 34              2024-01-14
# 592                 12              2024-01-03
# 10                  31              2024-01-05
# 418                 28              2024-01-14

# %% [markdown]
# ## 4. Datos de Escenarios con Costos Logísticos

# %%
Costos_Logisticos = pd.read_csv('Costos_Logisticos.csv')

# %%
Costos_Logisticos
# Out:
#      Escenario  costo_pedido  costo_mantenimiento_anual  \
# 0  Escenario 1          10.0                       0.15
# 1  Escenario 2          40.0                       0.20
# 2  Escenario 3          50.0                       0.25
# 3  Escenario 4          55.0                       0.30
# 4  Escenario 5          60.0                       0.35
#
#    costo_almacenamiento_m2  costo_transferencia_tienda  costo_rotura_stock  \
# 0                     80.0                         3.0                0.20
# 1                    100.0                         4.0                0.25
# 2                    120.0                         5.0                0.30
# 3                    130.0                         6.0                0.35
# 4                    140.0                         7.0                0.38
#
#    costo_obsolescencia
# 0                 0.09
# 1                 0.12
# 2                 0.15
# 3                 0.18
# 4                 0.20

# %% [markdown]
# ## Modelos Prescriptivos

# %% [markdown]
# ## 1: Sistema de Revisión Continua (s, Q) Optimizado

# %% [markdown]
# ### Sistema de revisión continua de inventarios: Definición, métodos y ejemplos
# https://www.ingenioempresa.com/sistema-de-revision-continua/#:~:text=de%20revisi%C3%B3n%20continua-,%C2%BFQu%C3%A9%20es%20un%20sistema%20de%20revisi%C3%B3n%20continua%20de%20inventarios?,debajo%20del%20nivel%2C%20sigue%20consumi%C3%A9ndose.

# %% [markdown]
# ## 2: Proponer 3 modelos prescriptivos adicionales, tomando en consideración los datos de los escenarios de  Costos_Logisticos
#
#    - **Optimización Multi-Periodo con Programación Lineal**
#    - **Sistema de Transferencias entre Tiendas**
#    - **Si es necesario emplear modelo como forecasting, regresiones**

# %% [markdown]
# ## 3: Proponer Dashboard de Control Prescriptivo
